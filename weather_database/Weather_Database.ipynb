# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\akank\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\akank\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90,2000)
lngs = np.random.uniform(-90,90,2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
import sys

# adding config_file/subfolder to the system path
sys.path.insert(0, '/Users/akank/Desktop/Github/World_Weather_Analysis/Weather_Database')

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

# %%
url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=4fdc7c5e00f1f61776525e729d322bea'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Loop through all the cities in the list.
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        #city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        
       # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
                          #"Current Description" : city_weather_descripton})
                         
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sandnessjoen
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | la rioja
# Processing Record 6 of Set 1 | kruisfontein
# Processing Record 7 of Set 1 | upernavik
# Processing Record 8 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 1 | nacala
# Processing Record 10 of Set 1 | umm lajj
# Processing Record 11 of Set 1 | altayskoye
# Processing Record 12 of Set 1 | peniche
# Processing Record 13 of Set 1 | tessalit
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | buraydah
# Processing Record 16 of Set 1 | havre-saint-pierre
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | mayumba
# Processing Record 19 of Set 1 | muscat
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | port shepstone
# Processing Record 22 of Set 1 | pisco
# Processing Record 23 of Set 1 | bell ville
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | matagami
# Processing Record 26 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 1 | barra do garcas
# Processing Record 28 of Set 1 | vila velha
# Processing Record 29 of Set 1 | koscierzyna
# Processing Record 30 of Set 1 | mazagao
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | khartoum
# Processing Record 33 of Set 1 | coquimbo
# Processing Record 34 of Set 1 | presidente epitacio
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | dawlatabad
# Processing Record 38 of Set 1 | vesoul
# Processing Record 39 of Set 1 | khormuj
# City not found. Skipping...
# Processing Record 40 of Set 1 | taoudenni
# Processing Record 41 of Set 1 | trofors
# Processing Record 42 of Set 1 | bandarbeyla
# Processing Record 43 of Set 1 | ayorou
# Processing Record 44 of Set 1 | namibe
# Processing Record 45 of Set 1 | namwala
# Processing Record 46 of Set 1 | harper
# Processing Record 47 of Set 1 | itaituba
# Processing Record 48 of Set 1 | los llanos de aridane
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | lagoa
# Processing Record 1 of Set 2 | burica
# City not found. Skipping...
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | vagay
# Processing Record 4 of Set 2 | sisimiut
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | thiadiaye
# Processing Record 7 of Set 2 | banki
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | clearwater
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | otukpo
# Processing Record 12 of Set 2 | muromtsevo
# Processing Record 13 of Set 2 | cidreira
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | castlerea
# Processing Record 16 of Set 2 | mecca
# Processing Record 17 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 18 of Set 2 | rocha
# Processing Record 19 of Set 2 | neuquen
# Processing Record 20 of Set 2 | kostino
# Processing Record 21 of Set 2 | guliston
# Processing Record 22 of Set 2 | changuinola
# Processing Record 23 of Set 2 | marawi
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | pindiga
# Processing Record 26 of Set 2 | usinsk
# Processing Record 27 of Set 2 | ponta do sol
# Processing Record 28 of Set 2 | balkhash
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | agirish
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | augustow
# Processing Record 33 of Set 2 | milton keynes
# Processing Record 34 of Set 2 | aden
# Processing Record 35 of Set 2 | kismayo
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | kargopol
# Processing Record 38 of Set 2 | sao joao da barra
# Processing Record 39 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 2 | quelimane
# Processing Record 41 of Set 2 | kaabong
# Processing Record 42 of Set 2 | rudbar
# Processing Record 43 of Set 2 | campos belos
# Processing Record 44 of Set 2 | san ignacio
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | iqaluit
# Processing Record 48 of Set 2 | yar-sale
# Processing Record 49 of Set 2 | bageshwar
# Processing Record 50 of Set 2 | jalu
# Processing Record 1 of Set 3 | mitsamiouli
# Processing Record 2 of Set 3 | demidov
# Processing Record 3 of Set 3 | port alfred
# Processing Record 4 of Set 3 | kibala
# Processing Record 5 of Set 3 | taloqan
# Processing Record 6 of Set 3 | machilipatnam
# Processing Record 7 of Set 3 | urfa
# City not found. Skipping...
# Processing Record 8 of Set 3 | san antonio
# Processing Record 9 of Set 3 | zhanakorgan
# Processing Record 10 of Set 3 | saint-pierre
# Processing Record 11 of Set 3 | cuamba
# Processing Record 12 of Set 3 | kapuskasing
# Processing Record 13 of Set 3 | sorland
# Processing Record 14 of Set 3 | san carlos de bariloche
# Processing Record 15 of Set 3 | iranshahr
# Processing Record 16 of Set 3 | asyut
# Processing Record 17 of Set 3 | ikom
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | puerto montt
# Processing Record 21 of Set 3 | shatura
# Processing Record 22 of Set 3 | snezhnogorsk
# Processing Record 23 of Set 3 | vasto
# Processing Record 24 of Set 3 | najran
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 3 | bria
# Processing Record 29 of Set 3 | amalapuram
# Processing Record 30 of Set 3 | aksum
# Processing Record 31 of Set 3 | sistranda
# Processing Record 32 of Set 3 | marsh harbour
# Processing Record 33 of Set 3 | kuusamo
# Processing Record 34 of Set 3 | klaksvik
# Processing Record 35 of Set 3 | echternach
# Processing Record 36 of Set 3 | guadix
# Processing Record 37 of Set 3 | dudinka
# Processing Record 38 of Set 3 | speedway
# Processing Record 39 of Set 3 | ornskoldsvik
# Processing Record 40 of Set 3 | tambura
# Processing Record 41 of Set 3 | tabou
# Processing Record 42 of Set 3 | longyearbyen
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | nouakchott
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | porto novo
# Processing Record 47 of Set 3 | qeshm
# Processing Record 48 of Set 3 | aswan
# Processing Record 49 of Set 3 | konibodom
# Processing Record 50 of Set 3 | souillac
# Processing Record 1 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 2 of Set 4 | ladario
# Processing Record 3 of Set 4 | saint-joseph
# Processing Record 4 of Set 4 | chuy
# Processing Record 5 of Set 4 | susangerd
# Processing Record 6 of Set 4 | maceio
# Processing Record 7 of Set 4 | sao bras de alportel
# Processing Record 8 of Set 4 | calamar
# Processing Record 9 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 4 | bartica
# Processing Record 11 of Set 4 | feltre
# Processing Record 12 of Set 4 | tombouctou
# Processing Record 13 of Set 4 | iguape
# Processing Record 14 of Set 4 | hualmay
# Processing Record 15 of Set 4 | victoria
# Processing Record 16 of Set 4 | adrar
# Processing Record 17 of Set 4 | maniitsoq
# Processing Record 18 of Set 4 | villa del rosario
# Processing Record 19 of Set 4 | bambous virieux
# Processing Record 20 of Set 4 | porto empedocle
# Processing Record 21 of Set 4 | antofagasta
# Processing Record 22 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 4 | youkounkoun
# Processing Record 24 of Set 4 | zorritos
# Processing Record 25 of Set 4 | eyrarbakki
# Processing Record 26 of Set 4 | konosha
# Processing Record 27 of Set 4 | comodoro rivadavia
# Processing Record 28 of Set 4 | shadrinsk
# Processing Record 29 of Set 4 | minab
# Processing Record 30 of Set 4 | olinda
# Processing Record 31 of Set 4 | westport
# Processing Record 32 of Set 4 | inhambane
# Processing Record 33 of Set 4 | tazovskiy
# Processing Record 34 of Set 4 | ankazoabo
# Processing Record 35 of Set 4 | purranque
# Processing Record 36 of Set 4 | beyneu
# Processing Record 37 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 38 of Set 4 | polyarnyye zori
# Processing Record 39 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 4 | rivadavia
# Processing Record 41 of Set 4 | walsrode
# Processing Record 42 of Set 4 | ostrovnoy
# Processing Record 43 of Set 4 | kutum
# Processing Record 44 of Set 4 | san ramon
# Processing Record 45 of Set 4 | krasnomayskiy
# Processing Record 46 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 4 | colombia
# Processing Record 48 of Set 4 | razole
# Processing Record 49 of Set 4 | touros
# Processing Record 50 of Set 4 | terrace bay
# Processing Record 1 of Set 5 | suez
# Processing Record 2 of Set 5 | matara
# Processing Record 3 of Set 5 | valdivia
# Processing Record 4 of Set 5 | boysun
# Processing Record 5 of Set 5 | shemonaikha
# Processing Record 6 of Set 5 | dingle
# Processing Record 7 of Set 5 | forestville
# Processing Record 8 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | kozhva
# Processing Record 11 of Set 5 | comarapa
# Processing Record 12 of Set 5 | pitimbu
# Processing Record 13 of Set 5 | mahibadhoo
# Processing Record 14 of Set 5 | sinnamary
# Processing Record 15 of Set 5 | nanortalik
# Processing Record 16 of Set 5 | dwarka
# Processing Record 17 of Set 5 | hambantota
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | aku
# Processing Record 20 of Set 5 | vardo
# Processing Record 21 of Set 5 | teguise
# Processing Record 22 of Set 5 | adre
# Processing Record 23 of Set 5 | barra
# Processing Record 24 of Set 5 | grand gaube
# Processing Record 25 of Set 5 | dzaoudzi
# Processing Record 26 of Set 5 | atar
# Processing Record 27 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 5 | valledupar
# Processing Record 29 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 5 | muravlenko
# Processing Record 31 of Set 5 | ilulissat
# Processing Record 32 of Set 5 | tamandare
# Processing Record 33 of Set 5 | damghan
# Processing Record 34 of Set 5 | mortka
# Processing Record 35 of Set 5 | codrington
# Processing Record 36 of Set 5 | kindu
# Processing Record 37 of Set 5 | almazar
# Processing Record 38 of Set 5 | plouzane
# Processing Record 39 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 40 of Set 5 | san andres
# Processing Record 41 of Set 5 | natal
# Processing Record 42 of Set 5 | beloha
# Processing Record 43 of Set 5 | michurinsk
# Processing Record 44 of Set 5 | axim
# Processing Record 45 of Set 5 | narsaq
# Processing Record 46 of Set 5 | qarqin
# Processing Record 47 of Set 5 | luderitz
# Processing Record 48 of Set 5 | wukari
# Processing Record 49 of Set 5 | imbituba
# Processing Record 50 of Set 5 | ambovombe
# Processing Record 1 of Set 6 | kiruna
# Processing Record 2 of Set 6 | luanda
# Processing Record 3 of Set 6 | temnikov
# Processing Record 4 of Set 6 | margate
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | matsanga
# City not found. Skipping...
# Processing Record 7 of Set 6 | thinadhoo
# Processing Record 8 of Set 6 | nivala
# Processing Record 9 of Set 6 | muros
# Processing Record 10 of Set 6 | shajapur
# Processing Record 11 of Set 6 | alcudia
# Processing Record 12 of Set 6 | pemba
# Processing Record 13 of Set 6 | porto seguro
# Processing Record 14 of Set 6 | chaykovskiy
# Processing Record 15 of Set 6 | pangnirtung
# Processing Record 16 of Set 6 | salym
# Processing Record 17 of Set 6 | rio gallegos
# Processing Record 18 of Set 6 | caravelas
# Processing Record 19 of Set 6 | sayyan
# Processing Record 20 of Set 6 | puerto del rosario
# Processing Record 21 of Set 6 | bubaque
# Processing Record 22 of Set 6 | berlevag
# Processing Record 23 of Set 6 | quatre cocos
# Processing Record 24 of Set 6 | huarmey
# Processing Record 25 of Set 6 | chupa
# Processing Record 26 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 27 of Set 6 | novoagansk
# Processing Record 28 of Set 6 | sao geraldo do araguaia
# Processing Record 29 of Set 6 | itacare
# Processing Record 30 of Set 6 | vetlanda
# Processing Record 31 of Set 6 | aguimes
# Processing Record 32 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 6 | mbandaka
# Processing Record 34 of Set 6 | syumsi
# Processing Record 35 of Set 6 | zamosc
# Processing Record 36 of Set 6 | coihaique
# Processing Record 37 of Set 6 | atasu
# Processing Record 38 of Set 6 | saint anthony
# Processing Record 39 of Set 6 | itarema
# Processing Record 40 of Set 6 | bilma
# Processing Record 41 of Set 6 | hofn
# Processing Record 42 of Set 6 | am timan
# Processing Record 43 of Set 6 | yarkovo
# Processing Record 44 of Set 6 | maues
# Processing Record 45 of Set 6 | laguna
# Processing Record 46 of Set 6 | nantucket
# Processing Record 47 of Set 6 | strezhevoy
# Processing Record 48 of Set 6 | ahvaz
# Processing Record 49 of Set 6 | santa elena
# Processing Record 50 of Set 6 | cozumel
# Processing Record 1 of Set 7 | rawson
# Processing Record 2 of Set 7 | kyzyl-suu
# Processing Record 3 of Set 7 | kosonsoy
# Processing Record 4 of Set 7 | areosa
# Processing Record 5 of Set 7 | bonavista
# Processing Record 6 of Set 7 | bolkhov
# Processing Record 7 of Set 7 | carballo
# Processing Record 8 of Set 7 | fontem
# Processing Record 9 of Set 7 | gotha
# Processing Record 10 of Set 7 | tibati
# Processing Record 11 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 7 | acarau
# Processing Record 13 of Set 7 | krasnoselkup
# Processing Record 14 of Set 7 | saint george
# Processing Record 15 of Set 7 | kristiansund
# Processing Record 16 of Set 7 | svetlyy
# Processing Record 17 of Set 7 | wolkersdorf
# Processing Record 18 of Set 7 | barzas
# Processing Record 19 of Set 7 | panjab
# Processing Record 20 of Set 7 | islahiye
# Processing Record 21 of Set 7 | angren
# Processing Record 22 of Set 7 | nuuk
# Processing Record 23 of Set 7 | tunduru
# City not found. Skipping...
# Processing Record 24 of Set 7 | matozinhos
# Processing Record 25 of Set 7 | kulhudhuffushi
# Processing Record 26 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 27 of Set 7 | tromso
# Processing Record 28 of Set 7 | salinopolis
# Processing Record 29 of Set 7 | camabatela
# Processing Record 30 of Set 7 | les cayes
# Processing Record 31 of Set 7 | bathsheba
# Processing Record 32 of Set 7 | ilinskiy
# Processing Record 33 of Set 7 | himora
# City not found. Skipping...
# Processing Record 34 of Set 7 | key largo
# Processing Record 35 of Set 7 | north myrtle beach
# Processing Record 36 of Set 7 | bata
# Processing Record 37 of Set 7 | goderich
# Processing Record 38 of Set 7 | tir pol
# City not found. Skipping...
# Processing Record 39 of Set 7 | herat
# Processing Record 40 of Set 7 | sao filipe
# Processing Record 41 of Set 7 | mbanza-ngungu
# Processing Record 42 of Set 7 | oistins
# Processing Record 43 of Set 7 | barranca
# Processing Record 44 of Set 7 | carutapera
# Processing Record 45 of Set 7 | birao
# Processing Record 46 of Set 7 | cabedelo
# Processing Record 47 of Set 7 | gualaco
# Processing Record 48 of Set 7 | luau
# Processing Record 49 of Set 7 | calama
# Processing Record 50 of Set 7 | floriano
# Processing Record 1 of Set 8 | salinas
# Processing Record 2 of Set 8 | gwadar
# Processing Record 3 of Set 8 | puerto leguizamo
# Processing Record 4 of Set 8 | atkarsk
# Processing Record 5 of Set 8 | uyuni
# Processing Record 6 of Set 8 | santa isabel
# Processing Record 7 of Set 8 | adrian
# Processing Record 8 of Set 8 | west bay
# Processing Record 9 of Set 8 | raudeberg
# Processing Record 10 of Set 8 | meulaboh
# Processing Record 11 of Set 8 | zlitan
# Processing Record 12 of Set 8 | wamba
# Processing Record 13 of Set 8 | asfi
# Processing Record 14 of Set 8 | kamenka
# Processing Record 15 of Set 8 | menongue
# Processing Record 16 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 8 | gravdal
# Processing Record 18 of Set 8 | aksu
# Processing Record 19 of Set 8 | liverpool
# Processing Record 20 of Set 8 | kotelnich
# Processing Record 21 of Set 8 | hobyo
# Processing Record 22 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 8 | mahenge
# Processing Record 24 of Set 8 | gdov
# Processing Record 25 of Set 8 | mosquera
# Processing Record 26 of Set 8 | bondo
# Processing Record 27 of Set 8 | pangoa
# Processing Record 28 of Set 8 | floro
# Processing Record 29 of Set 8 | tres lagoas
# Processing Record 30 of Set 8 | gamba
# Processing Record 31 of Set 8 | susanino
# Processing Record 32 of Set 8 | dzilam gonzalez
# Processing Record 33 of Set 8 | talara
# Processing Record 34 of Set 8 | tatarsk
# Processing Record 35 of Set 8 | inyonga
# Processing Record 36 of Set 8 | staryy nadym
# Processing Record 37 of Set 8 | candido mendes
# Processing Record 38 of Set 8 | henties bay
# Processing Record 39 of Set 8 | parati
# Processing Record 40 of Set 8 | nouadhibou
# Processing Record 41 of Set 8 | ravar
# Processing Record 42 of Set 8 | saint-louis
# Processing Record 43 of Set 8 | sao jose da coroa grande
# Processing Record 44 of Set 8 | itapirapua
# Processing Record 45 of Set 8 | ilhabela
# Processing Record 46 of Set 8 | kishanpur
# Processing Record 47 of Set 8 | riyadh
# Processing Record 48 of Set 8 | ipora
# Processing Record 49 of Set 8 | kerouane
# Processing Record 50 of Set 8 | santa maria
# Processing Record 1 of Set 9 | tokzar
# City not found. Skipping...
# Processing Record 2 of Set 9 | nueve de julio
# Processing Record 3 of Set 9 | port blair
# Processing Record 4 of Set 9 | kuryk
# Processing Record 5 of Set 9 | maloy
# Processing Record 6 of Set 9 | tadpatri
# Processing Record 7 of Set 9 | aksarka
# Processing Record 8 of Set 9 | bud
# Processing Record 9 of Set 9 | kimberley
# Processing Record 10 of Set 9 | miraflores
# Processing Record 11 of Set 9 | santa cruz de tenerife
# Processing Record 12 of Set 9 | butembo
# Processing Record 13 of Set 9 | aramecina
# Processing Record 14 of Set 9 | sitio novo do tocantins
# Processing Record 15 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 16 of Set 9 | cururupu
# Processing Record 17 of Set 9 | mala
# Processing Record 18 of Set 9 | richards bay
# Processing Record 19 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 20 of Set 9 | clyde river
# Processing Record 21 of Set 9 | nizwa
# Processing Record 22 of Set 9 | nalut
# Processing Record 23 of Set 9 | santo andre
# Processing Record 24 of Set 9 | skiros
# City not found. Skipping...
# Processing Record 25 of Set 9 | milos
# Processing Record 26 of Set 9 | vestmannaeyjar
# Processing Record 27 of Set 9 | constantine
# Processing Record 28 of Set 9 | colesberg
# Processing Record 29 of Set 9 | marovoay
# Processing Record 30 of Set 9 | grindavik
# Processing Record 31 of Set 9 | palanga
# Processing Record 32 of Set 9 | sabya
# Processing Record 33 of Set 9 | oktyabrskoye
# Processing Record 34 of Set 9 | alta floresta
# Processing Record 35 of Set 9 | thiruvananthapuram
# Processing Record 36 of Set 9 | takoradi
# Processing Record 37 of Set 9 | campoverde
# Processing Record 38 of Set 9 | iskateley
# Processing Record 39 of Set 9 | mananjary
# Processing Record 40 of Set 9 | porteirinha
# Processing Record 41 of Set 9 | kabalo
# Processing Record 42 of Set 9 | bandar-e lengeh
# Processing Record 43 of Set 9 | loubomo
# Processing Record 44 of Set 9 | san carlos
# Processing Record 45 of Set 9 | santo antonio do ica
# Processing Record 46 of Set 9 | lyubeshiv
# City not found. Skipping...
# Processing Record 47 of Set 9 | saurimo
# Processing Record 48 of Set 9 | qasigiannguit
# Processing Record 49 of Set 9 | jutai
# Processing Record 50 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 1 of Set 10 | shache
# Processing Record 2 of Set 10 | semibratovo
# Processing Record 3 of Set 10 | chudniv
# Processing Record 4 of Set 10 | dalbandin
# Processing Record 5 of Set 10 | bengkulu
# Processing Record 6 of Set 10 | brae
# Processing Record 7 of Set 10 | coelho neto
# Processing Record 8 of Set 10 | havoysund
# Processing Record 9 of Set 10 | moose factory
# Processing Record 10 of Set 10 | aneho
# Processing Record 11 of Set 10 | joshimath
# Processing Record 12 of Set 10 | puerto ayacucho
# Processing Record 13 of Set 10 | mokrous
# Processing Record 14 of Set 10 | funadhoo
# Processing Record 15 of Set 10 | camacha
# Processing Record 16 of Set 10 | chimoio
# Processing Record 17 of Set 10 | neftcala
# Processing Record 18 of Set 10 | san pedro
# Processing Record 19 of Set 10 | baependi
# Processing Record 20 of Set 10 | gnjilane
# Processing Record 21 of Set 10 | santa rosa
# Processing Record 22 of Set 10 | nkayi
# Processing Record 23 of Set 10 | storforshei
# Processing Record 24 of Set 10 | cockburn town
# Processing Record 25 of Set 10 | borovskoy
# Processing Record 26 of Set 10 | barabinsk
# Processing Record 27 of Set 10 | manaus
# Processing Record 28 of Set 10 | geraldton
# Processing Record 29 of Set 10 | alegre
# Processing Record 30 of Set 10 | paamiut
# Processing Record 31 of Set 10 | dukhovshchina
# Processing Record 32 of Set 10 | knokke-heist
# Processing Record 33 of Set 10 | carnarvon
# Processing Record 34 of Set 10 | finnsnes
# Processing Record 35 of Set 10 | the valley
# Processing Record 36 of Set 10 | diffa
# Processing Record 37 of Set 10 | galle
# Processing Record 38 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 39 of Set 10 | guiratinga
# Processing Record 40 of Set 10 | saint-georges
# Processing Record 41 of Set 10 | swanzey
# Processing Record 42 of Set 10 | galbshtadt
# Processing Record 43 of Set 10 | jos
# Processing Record 44 of Set 10 | maragogi
# Processing Record 45 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 10 | aleksandrov gay
# Processing Record 47 of Set 10 | malakal
# Processing Record 48 of Set 10 | diamantino
# Processing Record 49 of Set 10 | cayenne
# Processing Record 50 of Set 10 | tortoli
# Processing Record 1 of Set 11 | trincomalee
# Processing Record 2 of Set 11 | stykkisholmur
# Processing Record 3 of Set 11 | mweka
# Processing Record 4 of Set 11 | stephenville
# Processing Record 5 of Set 11 | angoche
# Processing Record 6 of Set 11 | hukuntsi
# Processing Record 7 of Set 11 | pontecorvo
# Processing Record 8 of Set 11 | sept-iles
# Processing Record 9 of Set 11 | shakhtinsk
# Processing Record 10 of Set 11 | maglajani
# Processing Record 11 of Set 11 | mao
# Processing Record 12 of Set 11 | gardez
# Processing Record 13 of Set 11 | two rivers
# Processing Record 14 of Set 11 | phalodi
# Processing Record 15 of Set 11 | bereznik
# Processing Record 16 of Set 11 | keetmanshoop
# Processing Record 17 of Set 11 | husavik
# Processing Record 18 of Set 11 | vangaindrano
# Processing Record 19 of Set 11 | salvador
# Processing Record 20 of Set 11 | vieste
# Processing Record 21 of Set 11 | olafsvik
# Processing Record 22 of Set 11 | bereda
# Processing Record 23 of Set 11 | qandala
# Processing Record 24 of Set 11 | korla
# Processing Record 25 of Set 11 | misratah
# Processing Record 26 of Set 11 | samaipata
# Processing Record 27 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 28 of Set 11 | songadh
# Processing Record 29 of Set 11 | garissa
# Processing Record 30 of Set 11 | zhanaozen
# Processing Record 31 of Set 11 | paita
# Processing Record 32 of Set 11 | shawinigan
# Processing Record 33 of Set 11 | aland
# Processing Record 34 of Set 11 | bodrum
# Processing Record 35 of Set 11 | vila franca do campo
# Processing Record 36 of Set 11 | archidona
# Processing Record 37 of Set 11 | dennery
# Processing Record 38 of Set 11 | hopewell
# Processing Record 39 of Set 11 | coulihaut
# City not found. Skipping...
# Processing Record 40 of Set 11 | hof
# Processing Record 41 of Set 11 | sambava
# Processing Record 42 of Set 11 | veraval
# Processing Record 43 of Set 11 | surt
# Processing Record 44 of Set 11 | mana
# Processing Record 45 of Set 11 | lindsay
# Processing Record 46 of Set 11 | karaton
# Processing Record 47 of Set 11 | mabaruma
# Processing Record 48 of Set 11 | hamilton
# Processing Record 49 of Set 11 | autazes
# Processing Record 50 of Set 11 | omboue
# Processing Record 1 of Set 12 | horbranz
# Processing Record 2 of Set 12 | scarborough
# Processing Record 3 of Set 12 | vigrestad
# Processing Record 4 of Set 12 | sao raimundo das mangabeiras
# Processing Record 5 of Set 12 | katesh
# Processing Record 6 of Set 12 | redcliffe
# Processing Record 7 of Set 12 | batsfjord
# Processing Record 8 of Set 12 | santiago de cao
# Processing Record 9 of Set 12 | clermont
# Processing Record 10 of Set 12 | bapatla
# Processing Record 11 of Set 12 | padre paraiso
# Processing Record 12 of Set 12 | lagunillas
# Processing Record 13 of Set 12 | maku
# Processing Record 14 of Set 12 | awbari
# Processing Record 15 of Set 12 | tomar
# Processing Record 16 of Set 12 | yurginskoye
# Processing Record 17 of Set 12 | bethlehem
# Processing Record 18 of Set 12 | shirokaya rechka
# Processing Record 19 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 21 of Set 12 | bodden town
# Processing Record 22 of Set 12 | virtsu
# Processing Record 23 of Set 12 | den helder
# Processing Record 24 of Set 12 | kirovskaya
# Processing Record 25 of Set 12 | waddan
# Processing Record 26 of Set 12 | chimore
# Processing Record 27 of Set 12 | oranjemund
# Processing Record 28 of Set 12 | antalaha
# Processing Record 29 of Set 12 | mansa
# Processing Record 30 of Set 12 | shalakusha
# Processing Record 31 of Set 12 | faya
# Processing Record 32 of Set 12 | tabas
# Processing Record 33 of Set 12 | ratnagiri
# Processing Record 34 of Set 12 | upington
# Processing Record 35 of Set 12 | burgersdorp
# Processing Record 36 of Set 12 | sharjah
# Processing Record 37 of Set 12 | tandalti
# Processing Record 38 of Set 12 | podstepki
# Processing Record 39 of Set 12 | chivolo
# Processing Record 40 of Set 12 | damme
# Processing Record 41 of Set 12 | muzhi
# Processing Record 42 of Set 12 | carauari
# Processing Record 43 of Set 12 | sinazongwe
# Processing Record 44 of Set 12 | lasa
# Processing Record 45 of Set 12 | tostamaa
# City not found. Skipping...
# Processing Record 46 of Set 12 | abu dhabi
# Processing Record 47 of Set 12 | kavaratti
# Processing Record 48 of Set 12 | sao bartolomeu de messines
# Processing Record 49 of Set 12 | idah
# Processing Record 50 of Set 12 | calvinia
# Processing Record 1 of Set 13 | kizema
# Processing Record 2 of Set 13 | saint-francois
# Processing Record 3 of Set 13 | bandundu
# Processing Record 4 of Set 13 | ilembula
# Processing Record 5 of Set 13 | itamaraca
# Processing Record 6 of Set 13 | trairi
# Processing Record 7 of Set 13 | boca do acre
# Processing Record 8 of Set 13 | necochea
# Processing Record 9 of Set 13 | zabol
# Processing Record 10 of Set 13 | la romana
# Processing Record 11 of Set 13 | havelock
# Processing Record 12 of Set 13 | pimenta bueno
# Processing Record 13 of Set 13 | verkhnyaya inta
# Processing Record 14 of Set 13 | sawakin
# Processing Record 15 of Set 13 | leshukonskoye
# Processing Record 16 of Set 13 | bonthe
# Processing Record 17 of Set 13 | huancabamba
# Processing Record 18 of Set 13 | nicoya
# Processing Record 19 of Set 13 | dipkarpaz
# City not found. Skipping...
# Processing Record 20 of Set 13 | inongo
# Processing Record 21 of Set 13 | taltal
# Processing Record 22 of Set 13 | gus-zheleznyy
# Processing Record 23 of Set 13 | shelburne
# Processing Record 24 of Set 13 | manta
# Processing Record 25 of Set 13 | oleksandrivka
# Processing Record 26 of Set 13 | turayf
# Processing Record 27 of Set 13 | honningsvag
# Processing Record 28 of Set 13 | yusva
# City not found. Skipping...
# Processing Record 29 of Set 13 | ussel
# Processing Record 30 of Set 13 | bambari
# Processing Record 31 of Set 13 | bahar
# Processing Record 32 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 33 of Set 13 | uyskoye
# Processing Record 34 of Set 13 | aparecida do taboado
# Processing Record 35 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 13 | kangaatsiaq
# Processing Record 37 of Set 13 | aripuana
# Processing Record 38 of Set 13 | kumbo
# Processing Record 39 of Set 13 | chapais
# Processing Record 40 of Set 13 | lagos
# Processing Record 41 of Set 13 | cascais
# Processing Record 42 of Set 13 | tandil
# Processing Record 43 of Set 13 | luena
# Processing Record 44 of Set 13 | florianopolis
# Processing Record 45 of Set 13 | melilla
# Processing Record 46 of Set 13 | morgantown
# Processing Record 47 of Set 13 | ustrzyki dolne
# Processing Record 48 of Set 13 | cervo
# Processing Record 49 of Set 13 | kargasok
# Processing Record 50 of Set 13 | galdar
# Processing Record 1 of Set 14 | suamico
# Processing Record 2 of Set 14 | ipanema
# Processing Record 3 of Set 14 | oranjestad
# Processing Record 4 of Set 14 | acari
# Processing Record 5 of Set 14 | gornopravdinsk
# Processing Record 6 of Set 14 | sabang
# Processing Record 7 of Set 14 | syracuse
# Processing Record 8 of Set 14 | staroaleyskoye
# Processing Record 9 of Set 14 | hearst
# Processing Record 10 of Set 14 | kisangani
# Processing Record 11 of Set 14 | jawa
# Processing Record 12 of Set 14 | tamale
# Processing Record 13 of Set 14 | amapa
# Processing Record 14 of Set 14 | kudahuvadhoo
# Processing Record 15 of Set 14 | araouane
# Processing Record 16 of Set 14 | tukrah
# Processing Record 17 of Set 14 | caparica
# Processing Record 18 of Set 14 | waycross
# Processing Record 19 of Set 14 | conde
# Processing Record 20 of Set 14 | baglung
# Processing Record 21 of Set 14 | gidole
# Processing Record 22 of Set 14 | kiyasovo
# Processing Record 23 of Set 14 | salalah
# Processing Record 24 of Set 14 | rabo de peixe
# Processing Record 25 of Set 14 | impfondo
# Processing Record 26 of Set 14 | chatham
# Processing Record 27 of Set 14 | kalomo
# City not found. Skipping...
# Processing Record 28 of Set 14 | yenagoa
# Processing Record 29 of Set 14 | rio bueno
# Processing Record 30 of Set 14 | tabulbah
# City not found. Skipping...
# Processing Record 31 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 32 of Set 14 | yambio
# Processing Record 33 of Set 14 | iglino
# Processing Record 34 of Set 14 | chicama
# Processing Record 35 of Set 14 | kautokeino
# Processing Record 36 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 37 of Set 14 | kaduqli
# Processing Record 38 of Set 14 | winsum
# Processing Record 39 of Set 14 | buchanan
# Processing Record 40 of Set 14 | kontagora
# Processing Record 41 of Set 14 | edd
# Processing Record 42 of Set 14 | zaozerne
# Processing Record 43 of Set 14 | ous
# Processing Record 44 of Set 14 | vadso
# Processing Record 45 of Set 14 | el balyana
# City not found. Skipping...
# Processing Record 46 of Set 14 | polunochnoye
# Processing Record 47 of Set 14 | ginir
# Processing Record 48 of Set 14 | san cristobal
# Processing Record 49 of Set 14 | sovetskiy
# Processing Record 50 of Set 14 | gat
# Processing Record 1 of Set 15 | skibbereen
# Processing Record 2 of Set 15 | fort-shevchenko
# Processing Record 3 of Set 15 | sao miguel do araguaia
# Processing Record 4 of Set 15 | roald
# Processing Record 5 of Set 15 | naryan-mar
# Processing Record 6 of Set 15 | tucupita
# Processing Record 7 of Set 15 | port-gentil
# Processing Record 8 of Set 15 | taraclia
# Processing Record 9 of Set 15 | srednyaya yelyuzan
# Processing Record 10 of Set 15 | aljezur
# Processing Record 11 of Set 15 | trelew
# Processing Record 12 of Set 15 | schwechat
# Processing Record 13 of Set 15 | manoel urbano
# Processing Record 14 of Set 15 | kayes
# Processing Record 15 of Set 15 | bacalar
# Processing Record 16 of Set 15 | kibara
# Processing Record 17 of Set 15 | alta gracia
# Processing Record 18 of Set 15 | porto murtinho
# Processing Record 19 of Set 15 | benjamin constant
# Processing Record 20 of Set 15 | viedma
# Processing Record 21 of Set 15 | chaparral
# Processing Record 22 of Set 15 | okakarara
# Processing Record 23 of Set 15 | gulshat
# City not found. Skipping...
# Processing Record 24 of Set 15 | durazno
# Processing Record 25 of Set 15 | odweyne
# Processing Record 26 of Set 15 | gari
# Processing Record 27 of Set 15 | shabrovskiy
# Processing Record 28 of Set 15 | mitu
# Processing Record 29 of Set 15 | mocuba
# Processing Record 30 of Set 15 | valparaiso
# Processing Record 31 of Set 15 | owo
# Processing Record 32 of Set 15 | acandi
# Processing Record 33 of Set 15 | samoylovka
# Processing Record 34 of Set 15 | groningen
# Processing Record 35 of Set 15 | sorkjosen
# Processing Record 36 of Set 15 | port-de-paix
# City not found. Skipping...
# Processing Record 37 of Set 15 | jumla
# Processing Record 38 of Set 15 | soto
# Processing Record 39 of Set 15 | kilrush
# Processing Record 40 of Set 15 | nara
# Processing Record 41 of Set 15 | mlimba
# Processing Record 42 of Set 15 | talnakh
# Processing Record 43 of Set 15 | sakakah
# Processing Record 44 of Set 15 | ponte san pietro
# Processing Record 45 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 15 | igrim
# Processing Record 47 of Set 15 | rochegda
# Processing Record 48 of Set 15 | senno
# Processing Record 49 of Set 15 | dolores
# Processing Record 50 of Set 15 | kasongo
# Processing Record 1 of Set 16 | beypur
# City not found. Skipping...
# Processing Record 2 of Set 16 | sayat
# Processing Record 3 of Set 16 | coria
# Processing Record 4 of Set 16 | hwange
# Processing Record 5 of Set 16 | matola
# Processing Record 6 of Set 16 | tefe
# Processing Record 7 of Set 16 | kozlovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
import pandas as pd
df = pd.DataFrame(city_data)
city_data_df = df.assign(Current_Description=city_weather['weather'][0]['description'])

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Sandnessjoen  66.0217  12.6316     48.42        94          75        6.91
# 1       Ushuaia -54.8000 -68.3000     40.66        75           0        1.14
# 2     Mahebourg -20.4081  57.7000     75.25        73          40       12.66
# 3      Hermanus -34.4187  19.2345     53.80        65          74        4.21
# 4      La Rioja  42.2500  -2.5000     46.18        54          46        5.88
# 5  Kruisfontein -34.0033  24.7314     56.88        76          50        8.34
# 6     Upernavik  72.7868 -56.1549     21.51        76         100        5.32
# 7        Nacala -14.5428  40.6728     78.37        62           2        6.17
# 8      Umm Lajj  25.0213  37.2685     83.61        57           0        3.24
# 9    Altayskoye  51.9533  85.3325     43.57        61           2        3.69
#
#   Country Current_Description
# 0      NO     overcast clouds
# 1      AR     overcast clouds
# 2      MU     overcast clouds
# 3      ZA     overcast clouds
# 4      ES     overcast clouds
# 5      ZA     overcast clouds
# 6      GL     overcast clouds
# 7      MZ     overcast clouds
# 8      SA     overcast clouds
# 9      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current_Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current_Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Sandnessjoen      NO  66.0217  12.6316     48.42        94          75
# 1       Ushuaia      AR -54.8000 -68.3000     40.66        75           0
# 2     Mahebourg      MU -20.4081  57.7000     75.25        73          40
# 3      Hermanus      ZA -34.4187  19.2345     53.80        65          74
# 4      La Rioja      ES  42.2500  -2.5000     46.18        54          46
# 5  Kruisfontein      ZA -34.0033  24.7314     56.88        76          50
# 6     Upernavik      GL  72.7868 -56.1549     21.51        76         100
# 7        Nacala      MZ -14.5428  40.6728     78.37        62           2
# 8      Umm Lajj      SA  25.0213  37.2685     83.61        57           0
# 9    Altayskoye      RU  51.9533  85.3325     43.57        61           2
#
#    Wind Speed Current_Description
# 0        6.91     overcast clouds
# 1        1.14     overcast clouds
# 2       12.66     overcast clouds
# 3        4.21     overcast clouds
# 4        5.88     overcast clouds
# 5        8.34     overcast clouds
# 6        5.32     overcast clouds
# 7        6.17     overcast clouds
# 8        3.24     overcast clouds
# 9        3.69     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current_Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "weather_database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
